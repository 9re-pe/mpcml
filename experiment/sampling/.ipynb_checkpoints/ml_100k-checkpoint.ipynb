# %% [markdown]
# # Import

# %%
import sys

#TODO: 相対パス
root_dir = '/Users/taichi/Library/CloudStorage/OneDrive-個人用/Documents/project/lab/bachelor/cml_pytorch2'
if root_dir not in sys.path:
    sys.path.append('/Users/taichi/Library/CloudStorage/OneDrive-個人用/Documents/project/lab/bachelor/cml_pytorch2')

import torch
from torch import nn, optim
import numpy as np
from sklearn.decomposition import TruncatedSVD
from scipy.sparse import csr_matrix
import matplotlib.pyplot as plt

from modules import losses, models, samplers, regularizers, evaluators, trainers, datasets, distributions

# %% [markdown]
# # DataSet

# %%
dataset = datasets.ML100k()
n_user = dataset.n_user
n_item = dataset.n_item
train_set, test_set = dataset.implicit_feedback_data(tail_threshold=20)

# device setting
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
train_set = torch.LongTensor(train_set).to(device)
test_set = torch.LongTensor(test_set).to(device)

# %% [markdown]
# # Evaluator

# %%
# k
ks = [50]

# Accuracy
score_function_dict = {
    "Recall": evaluators.recall
}
accuracy_evaluator = evaluators.AccuracyEvaluator(test_set, score_function_dict, ks)

# Unpopularity
unpopularity_evaluator = evaluators.UnpopularityEvaluator(test_set, ks)

# Hubness
hubness_evaluator = evaluators.HubnessEvaluator(test_set, ks)

# %% [markdown]
# # Sampler

# %%
sampler = samplers.BaseSampler(train_set, n_user, n_item, device=device, strict_negative=False)

# %% [markdown]
# # Model

# %%
# Hyperparameters
lr = 1e-3
n_dim = 50
n_batch = 256
n_epoch = 30
valid_per_epoch = 10
n_item_samples = [10, 20, 30, 40, 50]
n_user_samples = [10, 20, 30, 40, 50]
# もう一方のサンプル数を固定する
another_sample_num = 30
dist = distributions.Gamma()

def evaluate_result(evaluator, item_or_user):
    re = []
    
    if item_or_user == 'item':
        sample_nums = n_item_samples
    else:
        sample_nums = n_user_samples
    
    for sample_num in sample_nums:
        if item_or_user == 'item':
            model = models.MutualProximityCML(n_user, n_item, dist, n_dim, n_item_sample=sample_num, n_user_sample=another_sample_num).to(device)
        else:
            model = models.MutualProximityCML(n_user, n_item, dist, n_dim, n_item_sample=another_sample_num, n_user_sample=sample_num).to(device)
        optimizer = optim.Adam(model.parameters(), lr=lr)
        criterion = losses.SumTripletLoss(margin=1).to(device)
        trainer = trainers.BaseTrainer(model, optimizer, criterion, sampler)
        trainer.fit(n_batch, n_epoch, evaluator, valid_per_epoch)
        re.append(trainer.valid_scores.iloc[-1, 0])
    
    return re

# %% [markdown]
# # The number of item sample
# The number of sampling to computing parameters of the distribution of distances from a specific user to all items.

# %%
plt.plot(n_item_samples, evaluate_result(accuracy_evaluator, 'item'), marker='x')
plt.title('Effect of the number of item sample on Recall')
plt.xlabel('the number of item sample')
plt.ylabel('Recall')
plt.xticks(n_item_samples)
plt.show()
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 943/943 [01:21<00:00, 11.63it/s]

# %% [markdown]
# # The number of user sample
# The number of sampling to computing parameters of the distribution of distances from a specific item to all users.

# %%
plt.plot(n_user_samples, evaluate_result(accuracy_evaluator, 'user'), marker='x')
plt.title('Effect of the number of user sample on Recall')
plt.xlabel('the number of user sample')
plt.ylabel('Recall')
plt.xticks(n_user_samples)
plt.show()
# Out:
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████████████| 943/943 [01:47<00:00,  8.79it/s]
